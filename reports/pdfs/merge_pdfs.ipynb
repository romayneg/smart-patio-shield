# %%
#!pip install pypdf

from pypdf import PdfWriter

# Your files in the exact order requested
pdfs = [
    'Smart Patio Shield - Technical Documentation.pdf', 
    'src-data.pdf', 
    'src-features.pdf', 
    'src-models.pdf', 
    'deploy.pdf', 
    '01_weather_eda.pdf', 
    '02_feature_engineering.pdf', 
    '03_baseline_models.pdf', 
    '04_image_feasibility.pdf', 
    '05_cnn_modelling_colab.pdf', 
    '06_cnn_fusion_colab.pdf', 
    '07_motion_test_colab.pdf', 
    '08_convlstm_fusion_colab.pdf'
]

merger = PdfWriter()

for pdf in pdfs:
    merger.append(pdf)

merger.write("Smart Patio Shield - Technical Documentation (Master).pdf")
merger.close()
# Out:
# Annotation sizes differ: 31 vs. 0
# Annotation sizes differ: 25 vs. 0
# Annotation sizes differ: 2 vs. 0
# Annotation sizes differ: 2 vs. 0
# Annotation sizes differ: 3 vs. 0
# Annotation sizes differ: 2 vs. 0
# Annotation sizes differ: 3 vs. 0
# Annotation sizes differ: 2 vs. 0
# Annotation sizes differ: 1 vs. 0
# Annotation sizes differ: 1 vs. 0
# Annotation sizes differ: 2 vs. 0
# Annotation sizes differ: 5 vs. 0
# Annotation sizes differ: 1 vs. 0
# Annotation sizes differ: 1 vs. 0
# Annotation sizes differ: 2 vs. 0
# Annotation sizes differ: 5 vs. 0
# Annotation sizes differ: 1 vs. 0
# Annotation sizes differ: 1 vs. 0
# Annotation sizes differ: 2 vs. 0
# Annotation sizes differ: 1 vs. 0
# Annotation sizes differ: 1 vs. 0
# Annotation sizes differ: 2 vs. 0
